# %%
import pandas as pd
from pandas import DataFrame

df = pd.read_csv("./data/output.csv")
df = DataFrame(df).rename(columns={
  0: 'open',
  1: 'high',
  2: 'low',
  3: 'close',
  4: 'volume',
  5: 'created_at'
})

print(df)
# Out:
#    Unnamed: 0      0      1      2      3             4              5
# 0           0  22495  36800  21035  24928  3.789544e+04   2020/5/1 9:0
# 1           1  24894  27399  23381  24368  1.801368e+05   2020/6/1 9:0
# 2           2  24380  36963  24052  36734  5.283581e+05   2020/7/1 9:0
# 3           3  36753  47412  34861  46049  9.526664e+05   2020/8/1 9:0
# 4           4  46048  51699  33201  38000  1.242843e+06   2020/9/1 9:0
# 5           5  37995  43980  35257  40467  6.438336e+05  2020/10/1 9:0
# 6           6  40446  64600  39000  64000  1.296262e+06  2020/11/1 9:0
# 7           7  64000  77500  55112  75532  1.138962e+06  2020/12/1 9:0

# %%
df.plot(x="5", y="1", title="eth data", figsize=(12, 4))
# Out:
# <AxesSubplot:title={'center':'eth data'}, xlabel='5'>
